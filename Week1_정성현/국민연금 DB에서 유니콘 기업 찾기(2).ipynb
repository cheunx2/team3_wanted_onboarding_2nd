# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('company_nps_data.csv', encoding='cp949')
df.head()
# Out:
#      회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수
# 0  233757  41688077  2018   7   8912380      36
# 1  123464   1760695  2018   3    942380       5
# 2  342124   3221341  2018   7    781180       4
# 3  386420   4815584  2015  11   3795900      14
# 4  129243   9799736  2018  10  40724680     151

# %% [markdown]
# ## 시각화의 용이성을 위해 먼저 년도 칼럼과 월 칼럼을 합친 연월 칼럼 만들기

# %%
# 먼저 월 칼럼에 0을 추가한다. ex 07월, 03월, ...
df['월'] = df['월'].astype(str)
df['월'] = df['월'].str.zfill(2)
df
# Out:
#          회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수
# 0      233757  41688077  2018  07   8912380      36
# 1      123464   1760695  2018  03    942380       5
# 2      342124   3221341  2018  07    781180       4
# 3      386420   4815584  2015  11   3795900      14
# 4      129243   9799736  2018  10  40724680     151
# ...       ...       ...   ...  ..       ...     ...
# 99796  171439   4630622  2017  02   2402740      11
# 99797  239388   1045021  2018  10   1428800       9
# 99798  272304    181898  2018  03    392560       4
# 99799  362194   2100218  2018  12    874780       3
# 99800  124281    132900  2017  11    291940       5
#
# [99801 rows x 6 columns]

# %%
df['년도'] = df['년도'].astype(str)
df['연월'] = df['년도']+df['월']
df.head()
# Out:
#      회사ID      연매출액    년도   월  월별_연금보험료  월별_직원수      연월
# 0  233757  41688077  2018  07   8912380      36  201807
# 1  123464   1760695  2018  03    942380       5  201803
# 2  342124   3221341  2018  07    781180       4  201807
# 3  386420   4815584  2015  11   3795900      14  201511
# 4  129243   9799736  2018  10  40724680     151  201810

# %% [markdown]
# ## 3년치 이상의 데이터가 존재하는 기업만 분석
# 연매출이 증가하고 있는지 확인하기 위해서는 3년치 이상의 데이터가 필요하다고 결론

# %%
# 3년치 이상의 데이터가 존재하는 기업만 분석
회사_2015_list = set(df[df['년도']=='2015']['회사ID'].unique())
회사_2016_list = set(df[df['년도']=='2016']['회사ID'].unique())
회사_2017_list = set(df[df['년도']=='2017']['회사ID'].unique())
회사_2018_list = set(df[df['년도']=='2018']['회사ID'].unique())
회사_2019_list = set(df[df['년도']=='2019']['회사ID'].unique())

Group1 = 회사_2015_list & 회사_2016_list & 회사_2017_list
Group2 = 회사_2015_list & 회사_2016_list & 회사_2018_list
Group3 = 회사_2015_list & 회사_2016_list & 회사_2019_list
Group4 = 회사_2015_list & 회사_2017_list & 회사_2018_list
Group5 = 회사_2015_list & 회사_2017_list & 회사_2019_list
Group6 = 회사_2015_list & 회사_2018_list & 회사_2019_list

Group7 = 회사_2016_list & 회사_2017_list & 회사_2018_list
Group8 = 회사_2016_list & 회사_2017_list & 회사_2019_list
Group9 = 회사_2016_list & 회사_2018_list & 회사_2019_list

Group10 = 회사_2017_list & 회사_2018_list & 회사_2019_list

회사_3년치이상 = Group1 | Group2 | Group3 | Group4 | Group5 | Group6 | Group7 | Group8 | Group9 | Group10

len(회사_3년치이상)
# Out:
# 1645

# %%
회사_3년치이상 = list(회사_3년치이상)

# %%
# 회사_3년치이상의 인덱스만 추출
t_list = []
for num in 회사_3년치이상:
    include_idx = df[df['회사ID'] == num].index.to_list()
    for i in include_idx:
        t_list.append(i)
t_list
# Out:
# [1799,
#  3346,
#  10584,
#  11046,
#  11112,
#  11326,
#  12737,
#  13213,
#  19409,
#  21944,
#  25571,
#  27175,
#  27265,
#  27694,
#  28382,
#  31165,
#  37003,
#  37554,
#  37896,
#  40110,
#  42579,
#  50766,
#  52327,
#  54061,
#  56353,
#  56473,
#  60906,
#  61495,
#  73281,
#  80332,
#  81124,
#  87382,
#  87619,
#  87839,
#  88647,
#  89276,
#  91786,
#  91821,
#  1791,
#  4547,
#  7984,
#  8650,
#  15840,
#  18975,
#  20336,
#  23421,
#  25139,
#  29645,
#  31024,
#  32096,
#  34541,
#  43647,
#  44515,
#  50424,
#  56354,
#  57122,
#  57871,
#  58309,
#  62004,
#  62614,
#  64854,
#  65017,
#  65193,
#  65842,
#  69390,
#  78077,
#  80365,
#  84044,
#  86314,
#  86760,
#  88230,
#  90935,
#  91146,
#  92238,
#  94662,
#  95973,
#  10363,
#  14138,
#  18055,
#  19232,
#  24861,
#  28494,
#  29153,
#  29250,
#  29553,
#  31505,
#  37539,
#  42513,
#  43247,
#  48649,
#  54018,
#  54675,
#  60435,
#  64238,
#  64252,
#  73771,
#  77390,
#  78081,
#  79344,
#  84488,
#  93879,
#  95144,
#  1805,
#  2648,
#  5758,
#  8651,
#  14098,
#  16004,
#  16699,
#  19098,
#  22624,
#  24421,
#  27465,
#  30323,
#  34845,
#  35383,
#  38055,
#  40191,
#  46170,
#  48702,
#  53953,
#  55821,
#  56930,
#  58827,
#  61844,
#  62608,
#  65940,
#  69211,
#  71855,
#  72476,
#  77162,
#  78941,
#  85111,
#  85338,
#  85808,
#  88903,
#  90636,
#  91624,
#  96517,
#  96565,
#  2279,
#  7652,
#  10479,
#  12776,
#  13551,
#  15023,
#  19525,
#  19693,
#  19876,
#  23044,
#  29929,
#  33094,
#  34766,
#  37077,
#  39814,
#  41400,
#  42832,
#  42884,
#  43124,
#  47000,
#  47321,
#  48214,
#  48575,
#  62103,
#  64590,
#  66196,
#  72339,
#  74859,
#  77239,
#  79782,
#  82141,
#  86831,
#  89175,
#  92617,
#  93220,
#  94648,
#  345,
#  771,
#  1963,
#  4065,
#  4113,
#  5023,
#  6879,
#  6915,
#  7821,
#  8411,
#  12106,
#  12465,
#  12511,
#  12695,
#  13266,
#  13312,
#  27234,
#  35100,
#  36513,
#  39169,
#  45049,
#  47744,
#  49299,
#  60342,
#  65078,
#  65327,
#  66068,
#  69269,
#  70005,
#  78184,
#  83212,
#  87593,
#  87848,
#  90509,
#  93204,
#  99409,
#  2296,
#  7331,
#  7779,
#  13621,
#  16702,
#  18013,
#  18380,
#  23763,
#  27693,
#  33861,
#  36292,
#  37509,
#  38365,
#  39953,
#  40408,
#  40509,
#  40553,
#  46418,
#  48937,
#  64560,
#  67272,
#  68796,
#  71273,
#  75609,
#  76602,
#  78641,
#  80089,
#  80868,
#  81067,
#  87411,
#  89361,
#  92280,
#  97696,
#  98636,
#  99293,
#  99314,
#  4622,
#  5813,
#  8206,
#  8617,
#  10398,
#  13948,
#  21101,
#  25672,
#  26409,
#  28560,
#  31237,
#  35329,
#  35817,
#  41103,
#  41920,
#  42044,
#  42245,
#  43859,
#  44293,
#  44458,
#  53685,
#  54866,
#  55366,
#  57422,
#  59291,
#  64306,
#  65721,
#  68281,
#  71311,
#  76754,
#  78443,
#  78511,
#  78622,
#  79472,
#  83110,
#  94968,
#  7412,
#  7602,
#  8015,
#  11562,
#  12552,
#  13293,
#  15913,
#  17063,
#  19917,
#  23318,
#  29194,
#  32728,
#  36424,
#  45781,
#  45864,
#  49136,
#  49503,
#  51047,
#  53711,
#  58095,
#  58324,
#  60961,
#  63339,
#  63502,
#  65563,
#  65596,
#  65854,
#  66166,
#  69346,
#  72392,
#  74807,
#  75317,
#  75991,
#  84922,
#  85998,
#  87951,
#  87964,
#  89622,
#  4283,
#  12200,
#  12855,
#  14174,
#  19235,
#  23275,
#  24696,
#  31416,
#  32545,
#  38173,
#  44315,
#  46933,
#  47290,
#  50219,
#  50889,
#  52147,
#  53235,
#  54072,
#  55314,
#  57573,
#  61754,
#  71121,
#  75960,
#  84963,
#  86086,
#  13,
#  10194,
#  11091,
#  15350,
#  15824,
#  19636,
#  22374,
#  24246,
#  38917,
#  41501,
#  44836,
#  46606,
#  48540,
#  51890,
#  52124,
#  52224,
#  56010,
#  56337,
#  57711,
#  57872,
#  59458,
#  66277,
#  66390,
#  67026,
#  67742,
#  68418,
#  73609,
#  75564,
#  76859,
#  78773,
#  79552,
#  81943,
#  83457,
#  87145,
#  88331,
#  92029,
#  8195,
#  12127,
#  15139,
#  15141,
#  25271,
#  25382,
#  26004,
#  26508,
#  28260,
#  31859,
#  32053,
#  33848,
#  37501,
#  50566,
#  51329,
#  51995,
#  54928,
#  55724,
#  58612,
#  65270,
#  66440,
#  76350,
#  76842,
#  84587,
#  88432,
#  97423,
#  5656,
#  6988,
#  9889,
#  11813,
#  11822,
#  12479,
#  13003,
#  17453,
#  21683,
#  22009,
#  22577,
#  27470,
#  29983,
#  30748,
#  33891,
#  34648,
#  37056,
#  39910,
#  43648,
#  45724,
#  46523,
#  47797,
#  48596,
#  50430,
#  60111,
#  60700,
#  62717,
#  62860,
#  64864,
#  76834,
#  80154,
#  89378,
#  90216,
#  93120,
#  94034,
#  99069,
#  6221,
#  11662,
#  16107,
#  20062,
#  27715,
#  33990,
#  35510,
#  38966,
#  40668,
#  40805,
#  44190,
#  51567,
#  63252,
#  63685,
#  64654,
#  66029,
#  67781,
#  69745,
#  73650,
#  75647,
#  76006,
#  79526,
#  79565,
#  82466,
#  87755,
#  97288,
#  1118,
#  2224,
#  5167,
#  9131,
#  9899,
#  9964,
#  15292,
#  16622,
#  20522,
#  21377,
#  24418,
#  25388,
#  27148,
#  28399,
#  28845,
#  28951,
#  29198,
#  31337,
#  32421,
#  37330,
#  39963,
#  43013,
#  44675,
#  45672,
#  55906,
#  68844,
#  68893,
#  71250,
#  74753,
#  74787,
#  79431,
#  82394,
#  83189,
#  86433,
#  88959,
#  93569,
#  99404,
#  99460,
#  105,
#  9963,
#  11748,
#  13397,
#  15036,
#  17733,
#  19986,
#  21406,
#  27582,
#  28235,
#  33665,
#  35452,
#  38504,
#  41096,
#  44678,
#  48833,
#  52425,
#  61916,
#  65647,
#  68106,
#  71613,
#  78423,
#  86678,
#  93235,
#  95765,
#  96354,
#  1243,
#  4439,
#  7426,
#  8198,
#  8911,
#  12543,
#  15923,
#  23041,
#  34792,
#  37215,
#  39136,
#  39526,
#  40264,
#  42374,
#  43848,
#  45085,
#  48267,
#  50582,
#  51886,
#  53586,
#  62157,
#  65034,
#  69566,
#  75549,
#  90743,
#  97517,
#  806,
#  1750,
#  4942,
#  7996,
#  9517,
#  15098,
#  15954,
#  18670,
#  23610,
#  24191,
#  25741,
#  29993,
#  30946,
#  38171,
#  38382,
#  47519,
#  48004,
#  48796,
#  48841,
#  51510,
#  52695,
#  57533,
#  58325,
#  62737,
#  64097,
#  64159,
#  64399,
#  64408,
#  65937,
#  68612,
#  75666,
#  77734,
#  77890,
#  81956,
#  87300,
#  91122,
#  93846,
#  93966,
#  715,
#  812,
#  5029,
#  8552,
#  12583,
#  24287,
#  27526,
#  28175,
#  30032,
#  31530,
#  35188,
#  39582,
#  45706,
#  46379,
#  48199,
#  49917,
#  56690,
#  59896,
#  67691,
#  69613,
#  71696,
#  76138,
#  83353,
#  83356,
#  87473,
#  87809,
#  89337,
#  89883,
#  90426,
#  91792,
#  94344,
#  94661,
#  94663,
#  97009,
#  97902,
#  99200,
#  1039,
#  6689,
#  6765,
#  7636,
#  14226,
#  18403,
#  25038,
#  30357,
#  42079,
#  45191,
#  47837,
#  51228,
#  56575,
#  62983,
#  69682,
#  77756,
#  80523,
#  80865,
#  88196,
#  89738,
#  90407,
#  94416,
#  94804,
#  96780,
#  97391,
#  99490,
#  283,
#  321,
#  9110,
#  12450,
#  12964,
#  17411,
#  19304,
#  20526,
#  24126,
#  25160,
#  27440,
#  27598,
#  28641,
#  32506,
#  34096,
#  36085,
#  36180,
#  38660,
#  38964,
#  39345,
#  41368,
#  41373,
#  44860,
#  46318,
#  47573,
#  56026,
#  57034,
#  61007,
#  67106,
#  68187,
#  68366,
#  69725,
#  74364,
#  76647,
#  79715,
#  80622,
#  81338,
#  82073,
#  83764,
#  87743,
#  88756,
#  91506,
#  91736,
#  92141,
#  94872,
#  95737,
#  96073,
#  96889,
#  98163,
#  99406,
#  4928,
#  6743,
#  11824,
#  14193,
#  17865,
#  19022,
#  19351,
#  19697,
#  23908,
#  24483,
#  25626,
#  28212,
#  30074,
#  31346,
#  36799,
#  42250,
#  44067,
#  45736,
#  49843,
#  49877,
#  53485,
#  54712,
#  62815,
#  66182,
#  68396,
#  71736,
#  72912,
#  74223,
#  76604,
#  79899,
#  80099,
#  82591,
#  85685,
#  90507,
#  91988,
#  92800,
#  93884,
#  99483,
#  2670,
#  5807,
#  10071,
#  14656,
#  16565,
#  17233,
#  17409,
#  29641,
#  31272,
#  31389,
#  34123,
#  38515,
#  38788,
#  44805,
#  45694,
#  49251,
#  55780,
#  62597,
#  69341,
#  77780,
#  81226,
#  84360,
#  84780,
#  85328,
#  91222,
#  98118,
#  4147,
#  6559,
#  9791,
#  15911,
#  21093,
#  23159,
#  25533,
#  38800,
#  41524,
#  46977,
#  52514,
#  56108,
#  61578,
#  65713,
#  67036,
#  69232,
#  78765,
#  82044,
#  84472,
#  86480,
#  87551,
#  89639,
#  92262,
#  94660,
#  98906,
#  99572,
#  1630,
#  4976,
#  7871,
#  14157,
#  20817,
#  28829,
#  33246,
#  37335,
#  39069,
#  43626,
#  54171,
#  55886,
#  59378,
#  61508,
#  64603,
#  69327,
#  74038,
#  89469,
#  91794,
#  92172,
#  92623,
#  92999,
#  94465,
#  96215,
#  96604,
#  96758,
#  4420,
#  6382,
#  11009,
#  16258,
#  17681,
#  18482,
#  19347,
#  20846,
#  27189,
#  27475,
#  28531,
#  31012,
#  31136,
#  31216,
#  31641,
#  35195,
#  38344,
#  39437,
#  44436,
#  52513,
#  52883,
#  53187,
#  56436,
#  62644,
#  66179,
#  66329,
#  66451,
#  66650,
#  67552,
#  68586,
#  71595,
#  80980,
#  82482,
#  83558,
#  86449,
#  89002,
#  90258,
#  95009,
#  98,
#  2437,
#  2616,
#  7364,
#  7889,
#  10344,
#  12042,
#  13450,
#  14937,
#  16473,
#  20382,
#  20929,
#  25300,
#  26313,
#  32168,
#  33516,
#  34666,
#  37285,
#  37935,
#  39753,
#  40025,
#  40871,
#  45315,
#  53736,
#  55161,
#  60544,
#  62365,
#  67656,
#  68726,
#  69708,
#  80263,
#  89486,
#  89722,
#  90989,
#  91733,
#  97548,
#  99597,
#  99674,
#  1421,
#  5825,
#  7959,
#  10514,
#  11330,
#  11490,
#  16238,
#  24080,
#  26464,
#  28866,
#  31173,
#  35041,
#  35357,
#  38785,
#  46400,
#  56448,
#  68174,
#  73984,
#  79060,
#  79088,
#  80132,
#  84786,
#  92932,
#  96738,
#  98256,
#  98730,
#  684,
#  2109,
#  2356,
#  2497,
#  6324,
#  8979,
#  14078,
#  14213,
#  16727,
#  17365,
#  18166,
#  18209,
#  23092,
#  24699,
#  25027,
#  27336,
#  36241,
#  40855,
#  46882,
#  58279,
#  58702,
#  62871,
#  66407,
#  67574,
#  69070,
#  77566,
#  78031,
#  78618,
#  79517,
#  82268,
#  83337,
#  84442,
#  87206,
#  89477,
#  92570,
#  96138,
#  96208,
#  97876,
#  1722,
#  4746,
#  6359,
#  9484,
#  17939,
#  18764,
#  21233,
#  27324,
#  29661,
#  31836,
#  33430,
#  37441,
#  38639,
#  39517,
#  40781,
#  40937,
#  43055,
#  47001,
#  47980,
#  50923,
#  51852,
#  57874,
#  58898,
#  61262,
#  62363,
#  66944,
#  76512,
#  78566,
#  79636,
#  84139,
#  84415,
#  94715,
#  94842,
#  ...]

# %%
df2 = df.iloc[t_list]
df2
# Out:
#          회사ID     연매출액    년도   월  월별_연금보험료  월별_직원수      연월
# 1799   487425   136349  2016  02    624040       4  201602
# 3346   487425    99001  2017  12    632680       4  201712
# 10584  487425   136349  2016  09    634480       4  201609
# 11046  487425    99001  2017  10    632680       4  201710
# 11112  487425    99001  2017  06    634480       4  201706
# ...       ...      ...   ...  ..       ...     ...     ...
# 71025  434171  3123093  2017  01   1169000       4  201701
# 74316  434171  2776277  2019  05   1401020       4  201905
# 84674  434171  3123093  2017  11   1217160       4  201711
# 90977  434171  3123093  2017  08   1217160       4  201708
# 92201  434171  3123093  2017  12   1217160       4  201712
#
# [56024 rows x 7 columns]

# %% [markdown]
# ## 연매출액이 0원 이하인 기업들 제거

# %%
df2.sort_values('연매출액')
# Out:
#          회사ID         연매출액    년도   월   월별_연금보험료  월별_직원수      연월
# 37489  432911     -7882176  2017  11    1687760       5  201711
# 67889  432911     -7882176  2017  12    1687760       5  201712
# 64094  432911     -7882176  2017  03    2042620       6  201703
# 56276  432911     -7882176  2017  04    2042620       6  201704
# 51605  432911     -7882176  2017  06    2042620       6  201706
# ...       ...          ...   ...  ..        ...     ...     ...
# 88487  419945  10058868796  2019  06  870767520    2757  201906
# 25614  419945  10058868796  2019  07  928921380    2762  201907
# 13109  419945  10058868796  2019  04  870665760    2765  201904
# 70918  419945  10058868796  2019  08  927833840    2753  201908
# 72938  419945  10058868796  2019  03  865599660    2730  201903
#
# [56024 rows x 7 columns]

# %%
df2[df2['연매출액']<=0]['회사ID']
# Out:
# 7516     432911
# 7617     432911
# 8595     432911
# 23150    432911
# 36048    432911
# 37489    432911
# 51605    432911
# 56276    432911
# 64094    432911
# 67889    432911
# 93521    432911
# 95251    432911
# Name: 회사ID, dtype: int64

# %%
df2 = df2[df2['연매출액']>=0]

# %% [markdown]
# ## 월별 직원 수 혹은 월별 연금 보험료가 0인 기업들 제거

# %%
df2[(df2['월별_직원수']==0) | (df2['월별_연금보험료']==0)]['회사ID'].unique()
# Out:
# array([291968], dtype=int64)

# %%
df2[df2['회사ID']==291968]
# Out:
#          회사ID     연매출액    년도   월  월별_연금보험료  월별_직원수      연월
# 5855   291968  5015520  2017  10    717200       3  201710
# 19032  291968  4059302  2016  09    687600       3  201609
# 20459  291968  2694487  2015  12    774900       3  201512
# 23641  291968  5015520  2017  07    717200       3  201707
# 24049  291968  5015520  2017  06    687600       3  201706
# 31544  291968  5015520  2017  03    687600       3  201703
# 31617  291968  5015520  2017  01    687600       3  201701
# 33239  291968  4059302  2016  08    687600       3  201608
# 33416  291968  4059302  2016  11    687600       3  201611
# 36190  291968  5015520  2017  04    687600       3  201704
# 38040  291968  5015520  2017  09    717200       3  201709
# 44017  291968  2694487  2015  11    774900       3  201511
# 45967  291968  4059302  2016  05    675900       3  201605
# 48787  291968  5015520  2017  08    717200       3  201708
# 49592  291968  4059302  2016  04         0       0  201604
# 64972  291968  4059302  2016  02    774900       3  201602
# 66529  291968  4059302  2016  03    774900       3  201603
# 76558  291968  5015520  2017  11    730260       3  201711
# 76569  291968  4059302  2016  06    675900       3  201606
# 79295  291968  5015520  2017  12    719820       3  201712
# 84340  291968  5015520  2017  05    687600       3  201705
# 84605  291968  4059302  2016  07    687600       3  201607
# 87410  291968  4059302  2016  12    687600       3  201612
# 88074  291968  5015520  2017  02    687600       3  201702
# 90307  291968  4059302  2016  10    687600       3  201610
# 92671  291968  4059302  2016  01    774900       3  201601

# %%
df2 = df2[df2['회사ID']!=291968]

# %%
df2
# Out:
#          회사ID     연매출액    년도   월  월별_연금보험료  월별_직원수      연월
# 1799   487425   136349  2016  02    624040       4  201602
# 3346   487425    99001  2017  12    632680       4  201712
# 10584  487425   136349  2016  09    634480       4  201609
# 11046  487425    99001  2017  10    632680       4  201710
# 11112  487425    99001  2017  06    634480       4  201706
# ...       ...      ...   ...  ..       ...     ...     ...
# 71025  434171  3123093  2017  01   1169000       4  201701
# 74316  434171  2776277  2019  05   1401020       4  201905
# 84674  434171  3123093  2017  11   1217160       4  201711
# 90977  434171  3123093  2017  08   1217160       4  201708
# 92201  434171  3123093  2017  12   1217160       4  201712
#
# [55986 rows x 7 columns]

# %%
df2.sort_values(by=['회사ID','연월'])
# Out:
#          회사ID     연매출액    년도   월  월별_연금보험료  월별_직원수      연월
# 19588   14271  1199495  2015  11   2571840      11  201511
# 44251   14271  1199495  2015  12   3558780      15  201512
# 39783   14271  4257715  2016  01   3358340      15  201601
# 27519   14271  4257715  2016  02   3142340      14  201602
# 4503    14271  4257715  2016  03   3016340      13  201603
# ...       ...      ...   ...  ..       ...     ...     ...
# 80878  516653  1500046  2018  08    672380       5  201808
# 1653   516653  1500046  2018  09    672380       5  201809
# 58366  516653  1500046  2018  10    672380       5  201810
# 12394  516653  1500046  2018  11    672380       5  201811
# 53351  516653  1500046  2018  12    672380       5  201812
#
# [55986 rows x 7 columns]

# %% [markdown]
# ## 전년도(기록연도) 대비 연매출액 증감률 칼럼을 추가

# %%
df2['전년도(기록연도)_대비_매출액_증감률'] = df2.sort_values(['년도','연월']).groupby('회사ID')['연매출액'].pct_change()

# %%
df2 = df2[['회사ID','년도','월','연월','월별_연금보험료','월별_직원수','연매출액','전년도(기록연도)_대비_매출액_증감률']]
df2
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 1799   487425  2016  02  201602    624040       4   136349
# 3346   487425  2017  12  201712    632680       4    99001
# 10584  487425  2016  09  201609    634480       4   136349
# 11046  487425  2017  10  201710    632680       4    99001
# 11112  487425  2017  06  201706    634480       4    99001
# ...       ...   ...  ..     ...       ...     ...      ...
# 71025  434171  2017  01  201701   1169000       4  3123093
# 74316  434171  2019  05  201905   1401020       4  2776277
# 84674  434171  2017  11  201711   1217160       4  3123093
# 90977  434171  2017  08  201708   1217160       4  3123093
# 92201  434171  2017  12  201712   1217160       4  3123093
#
#        전년도(기록연도)_대비_매출액_증감률
# 1799               0.000000
# 3346               0.000000
# 10584              0.000000
# 11046              0.000000
# 11112              0.000000
# ...                     ...
# 71025             -0.142236
# 74316              0.000000
# 84674              0.000000
# 90977              0.000000
# 92201              0.000000
#
# [55986 rows x 8 columns]

# %%
# 전년도(기록연도) 대비 매출액 증감률만 보기
cond1 = (df2['전년도(기록연도)_대비_매출액_증감률'] != 0)
df3 = df2[cond1]
df3
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 40110  487425  2016  01  201601    624040       4   136349
# 81124  487425  2018  01  201801    632680       4   163475
# 87619  487425  2017  01  201701    634480       4    99001
# 91821  487425  2015  11  201511    624040       4   218917
# 29645  323588  2016  01  201601   1767860      10  3477394
# ...       ...   ...  ..     ...       ...     ...      ...
# 83622  442361  2016  01  201601   6913600      35  6566801
# 9420   434171  2015  11  201511   1244680       5  3604344
# 50583  434171  2016  01  201601   1112300       4  3640971
# 68902  434171  2019  01  201901    979820       3  2776277
# 71025  434171  2017  01  201701   1169000       4  3123093
#
#        전년도(기록연도)_대비_매출액_증감률
# 40110             -0.377166
# 81124              0.651246
# 87619             -0.273915
# 91821                   NaN
# 29645              0.170688
# ...                     ...
# 83622                   NaN
# 9420                    NaN
# 50583              0.010162
# 68902             -0.111049
# 71025             -0.142236
#
# [5808 rows x 8 columns]

# %%
df3 = df3.sort_values(['회사ID','연월'])
df3
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 19588   14271  2015  11  201511   2571840      11  1199495
# 39783   14271  2016  01  201601   3358340      15  4257715
# 27743   14271  2017  01  201701   3412760      15  5005248
# 87826   14271  2018  01  201801   3851360      18  8388401
# 6456    14271  2019  01  201901   4519140      22  9039340
# ...       ...   ...  ..     ...       ...     ...      ...
# 86889  515264  2017  01  201701    793680       5  2074820
# 70988  515264  2018  01  201801    743100       5  2422405
# 15828  516653  2016  01  201601    413260       4  1745520
# 52813  516653  2017  01  201701    449260       4  1956460
# 9804   516653  2018  01  201801    467720       4  1500046
#
#        전년도(기록연도)_대비_매출액_증감률
# 19588                   NaN
# 39783              2.549590
# 27743              0.175571
# 87826              0.675921
# 6456               0.077600
# ...                     ...
# 86889              0.393132
# 70988              0.167525
# 15828                   NaN
# 52813              0.120847
# 9804              -0.233286
#
# [5808 rows x 8 columns]

# %%
df3['전년도(기록연도)_대비_매출액_증감률(%)'] = df3['전년도(기록연도)_대비_매출액_증감률'] * 100
df3.drop('전년도(기록연도)_대비_매출액_증감률', axis=1, inplace=True)

# %%
df3
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 19588   14271  2015  11  201511   2571840      11  1199495
# 39783   14271  2016  01  201601   3358340      15  4257715
# 27743   14271  2017  01  201701   3412760      15  5005248
# 87826   14271  2018  01  201801   3851360      18  8388401
# 6456    14271  2019  01  201901   4519140      22  9039340
# ...       ...   ...  ..     ...       ...     ...      ...
# 86889  515264  2017  01  201701    793680       5  2074820
# 70988  515264  2018  01  201801    743100       5  2422405
# 15828  516653  2016  01  201601    413260       4  1745520
# 52813  516653  2017  01  201701    449260       4  1956460
# 9804   516653  2018  01  201801    467720       4  1500046
#
#        전년도(기록연도)_대비_매출액_증감률(%)
# 19588                      NaN
# 39783               254.958962
# 27743                17.557140
# 87826                67.592115
# 6456                  7.759989
# ...                        ...
# 86889                39.313150
# 70988                16.752538
# 15828                      NaN
# 52813                12.084651
# 9804                -23.328563
#
# [5808 rows x 8 columns]

# %% [markdown]
# ## 전처리 방법 고민 1
# - 가설: 전년(기록연도) 대비 매출액이 한번이라도 마이너스 성장하거나 성장 정체 한다면 유니콘 기업이 아니다.

# %%
tdf = df3[df3['전년도(기록연도)_대비_매출액_증감률(%)'] <= 0]
drop_id_list = tdf['회사ID'].unique().tolist()
tdf
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수      연매출액  \
# 53678   59533  2017  01  201701    552500       6    124299
# 42318  122968  2016  01  201601  15053500      73  26858719
# 80832  122968  2018  01  201801  13488300      63  31514468
# 71239  122983  2016  01  201601  12375020      62  20292461
# 41933  122983  2017  01  201701  11879000      59   9470987
# ...       ...   ...  ..     ...       ...     ...       ...
# 92306  512308  2018  01  201801   4770360      16   3562376
# 70733  513218  2017  01  201701   1177540       9   2482268
# 36883  514152  2016  01  201601   3004520       9   2088582
# 97165  514152  2018  01  201801   3225580      10   2578014
# 9804   516653  2018  01  201801    467720       4   1500046
#
#        전년도(기록연도)_대비_매출액_증감률(%)
# 53678               -40.172409
# 42318               -28.214758
# 80832                -4.495604
# 71239               -16.074402
# 41933               -53.327558
# ...                        ...
# 92306               -25.370870
# 70733                -1.853317
# 36883                -7.471335
# 97165                -0.368380
# 9804                -23.328563
#
# [1698 rows x 8 columns]

# %%
sum(tdf['전년도(기록연도)_대비_매출액_증감률(%)'].isna())
# Out:
# 0

# %%
# drop_id_list의 index만 추출
drop_index_list = []
for num in drop_id_list:
    idx = df2[df2['회사ID'] == num].index.to_list()
    for i in idx:
        drop_index_list.append(i)
drop_index_list
# Out:
# [3367,
#  10954,
#  13010,
#  18856,
#  18937,
#  19285,
#  20902,
#  24473,
#  25182,
#  31826,
#  33191,
#  36398,
#  40102,
#  40469,
#  41007,
#  43813,
#  43843,
#  45709,
#  48125,
#  51485,
#  51779,
#  53678,
#  61611,
#  61724,
#  62010,
#  62021,
#  62834,
#  64511,
#  64743,
#  67946,
#  75035,
#  77746,
#  79206,
#  82121,
#  83927,
#  88300,
#  91451,
#  97113,
#  1219,
#  2344,
#  4209,
#  7724,
#  17932,
#  18925,
#  19130,
#  21536,
#  23094,
#  34220,
#  42318,
#  46205,
#  46401,
#  51766,
#  53686,
#  58402,
#  59609,
#  61827,
#  63012,
#  66825,
#  71914,
#  75310,
#  75783,
#  78259,
#  80832,
#  81307,
#  87315,
#  87317,
#  87994,
#  90264,
#  90781,
#  91371,
#  91846,
#  91905,
#  93111,
#  93189,
#  94461,
#  99189,
#  1681,
#  4126,
#  8704,
#  16201,
#  19935,
#  33185,
#  36293,
#  41933,
#  47760,
#  47779,
#  52163,
#  55650,
#  58141,
#  60317,
#  62178,
#  68099,
#  71239,
#  73593,
#  81166,
#  81560,
#  84637,
#  85665,
#  86957,
#  92895,
#  94090,
#  98323,
#  3065,
#  9782,
#  13226,
#  18202,
#  21089,
#  21551,
#  28229,
#  37263,
#  40437,
#  45948,
#  53075,
#  57785,
#  59108,
#  60871,
#  64949,
#  67729,
#  67881,
#  68067,
#  70610,
#  71714,
#  73418,
#  73782,
#  74511,
#  77045,
#  78854,
#  80064,
#  81510,
#  82432,
#  82681,
#  85403,
#  85580,
#  85787,
#  86944,
#  88403,
#  90245,
#  96602,
#  1314,
#  3543,
#  7451,
#  9141,
#  10527,
#  15107,
#  17923,
#  19700,
#  19773,
#  26452,
#  29811,
#  39987,
#  40762,
#  42681,
#  45548,
#  47142,
#  48038,
#  50749,
#  51540,
#  53934,
#  54103,
#  55822,
#  62149,
#  65259,
#  66100,
#  67626,
#  70811,
#  75761,
#  77034,
#  79687,
#  82847,
#  88478,
#  89902,
#  96790,
#  97673,
#  98705,
#  2862,
#  5865,
#  6152,
#  9161,
#  14215,
#  23369,
#  29784,
#  30990,
#  34374,
#  40592,
#  41715,
#  43289,
#  44188,
#  47616,
#  48671,
#  48917,
#  52164,
#  55667,
#  57127,
#  59504,
#  67874,
#  71587,
#  72330,
#  73616,
#  74097,
#  76840,
#  76887,
#  78450,
#  85585,
#  88928,
#  90716,
#  90853,
#  91702,
#  91875,
#  93593,
#  96595,
#  96639,
#  97543,
#  1770,
#  3875,
#  10263,
#  21407,
#  22525,
#  23208,
#  23979,
#  28284,
#  29490,
#  30335,
#  35471,
#  40757,
#  42222,
#  50217,
#  51702,
#  54580,
#  64433,
#  68518,
#  69485,
#  70398,
#  76675,
#  77271,
#  84297,
#  92792,
#  92916,
#  94566,
#  1,
#  636,
#  1195,
#  4116,
#  5177,
#  7284,
#  9943,
#  10714,
#  17109,
#  18553,
#  23814,
#  28202,
#  39016,
#  41269,
#  41751,
#  41885,
#  43199,
#  43469,
#  44482,
#  46842,
#  47171,
#  47945,
#  50928,
#  52326,
#  52416,
#  58055,
#  61103,
#  69160,
#  69594,
#  71183,
#  71384,
#  72743,
#  78353,
#  83450,
#  96735,
#  97457,
#  628,
#  3202,
#  4307,
#  5211,
#  5963,
#  7539,
#  8213,
#  11192,
#  11251,
#  20198,
#  26763,
#  30529,
#  34266,
#  36813,
#  37289,
#  39691,
#  40092,
#  41369,
#  44148,
#  54317,
#  59890,
#  59944,
#  60665,
#  63475,
#  64463,
#  69726,
#  72192,
#  73427,
#  75316,
#  76000,
#  76894,
#  79297,
#  79730,
#  81010,
#  91445,
#  93744,
#  20,
#  1111,
#  1471,
#  5064,
#  9828,
#  12271,
#  13813,
#  17210,
#  19248,
#  19470,
#  20145,
#  20387,
#  22820,
#  23189,
#  24871,
#  30220,
#  33231,
#  39510,
#  40387,
#  52631,
#  52792,
#  61480,
#  63690,
#  65607,
#  69228,
#  74067,
#  77640,
#  79384,
#  80376,
#  82618,
#  85589,
#  86001,
#  88505,
#  91837,
#  94678,
#  94831,
#  454,
#  3084,
#  6723,
#  7459,
#  15034,
#  15786,
#  22058,
#  25993,
#  28053,
#  28972,
#  29322,
#  38003,
#  41352,
#  42799,
#  42866,
#  48194,
#  48337,
#  48354,
#  50619,
#  51176,
#  52878,
#  55721,
#  56079,
#  60576,
#  61294,
#  63464,
#  74810,
#  79995,
#  80167,
#  84755,
#  85289,
#  86875,
#  90029,
#  91152,
#  94198,
#  94971,
#  98130,
#  99800,
#  3926,
#  10405,
#  11389,
#  11590,
#  13071,
#  13655,
#  15455,
#  16063,
#  16655,
#  20801,
#  24399,
#  24666,
#  26697,
#  26925,
#  27823,
#  31255,
#  33698,
#  36039,
#  38888,
#  42760,
#  49613,
#  51374,
#  53966,
#  54792,
#  55006,
#  65657,
#  68272,
#  73058,
#  77468,
#  78939,
#  79746,
#  86324,
#  87013,
#  89465,
#  94239,
#  99310,
#  2438,
#  2835,
#  3145,
#  3165,
#  6779,
#  7753,
#  10560,
#  16615,
#  17706,
#  20088,
#  26466,
#  28149,
#  34451,
#  34863,
#  41175,
#  41294,
#  44918,
#  47993,
#  50962,
#  50980,
#  57519,
#  57743,
#  65242,
#  66580,
#  70878,
#  75220,
#  79749,
#  80745,
#  84100,
#  89080,
#  92640,
#  93113,
#  93913,
#  95494,
#  95617,
#  95718,
#  98448,
#  431,
#  4566,
#  6627,
#  7221,
#  10830,
#  16503,
#  22169,
#  24760,
#  32108,
#  34599,
#  35561,
#  39884,
#  40890,
#  41329,
#  45870,
#  49580,
#  50917,
#  54424,
#  55063,
#  57594,
#  59772,
#  60921,
#  63323,
#  65849,
#  67620,
#  68006,
#  70757,
#  72007,
#  74314,
#  74928,
#  75473,
#  82711,
#  82903,
#  83174,
#  85303,
#  89341,
#  90164,
#  95930,
#  2005,
#  2830,
#  4305,
#  7175,
#  9572,
#  9855,
#  13341,
#  13598,
#  23474,
#  25854,
#  29415,
#  29495,
#  34454,
#  35892,
#  36853,
#  39063,
#  39519,
#  39707,
#  41142,
#  45753,
#  51726,
#  64907,
#  69976,
#  72065,
#  79087,
#  80927,
#  82200,
#  82585,
#  87983,
#  89001,
#  90852,
#  91063,
#  97337,
#  97596,
#  98191,
#  6940,
#  7007,
#  7612,
#  11831,
#  28508,
#  35323,
#  35467,
#  37399,
#  40269,
#  40584,
#  41685,
#  43496,
#  45118,
#  54349,
#  56589,
#  57781,
#  59889,
#  59919,
#  59955,
#  60753,
#  60998,
#  65684,
#  66817,
#  71168,
#  71755,
#  78358,
#  78365,
#  78460,
#  79179,
#  82685,
#  85344,
#  86168,
#  90078,
#  90484,
#  91551,
#  95166,
#  95872,
#  98558,
#  6564,
#  9041,
#  18053,
#  18793,
#  28328,
#  29808,
#  34499,
#  50072,
#  51252,
#  54195,
#  55591,
#  57907,
#  59771,
#  63474,
#  64440,
#  64568,
#  71281,
#  73066,
#  74690,
#  76279,
#  76595,
#  77159,
#  80413,
#  88325,
#  89016,
#  98204,
#  1138,
#  5134,
#  5592,
#  6024,
#  6425,
#  18240,
#  22266,
#  28553,
#  31688,
#  34636,
#  41443,
#  46799,
#  47390,
#  47682,
#  50178,
#  53589,
#  55810,
#  64125,
#  64217,
#  67124,
#  74729,
#  75953,
#  77465,
#  79751,
#  80568,
#  81415,
#  81810,
#  85409,
#  87962,
#  89675,
#  91330,
#  93982,
#  96240,
#  97620,
#  99171,
#  99552,
#  1574,
#  1977,
#  5319,
#  17879,
#  22060,
#  22604,
#  28716,
#  39320,
#  42086,
#  53013,
#  58459,
#  61887,
#  62099,
#  66279,
#  68896,
#  70146,
#  71082,
#  77587,
#  84094,
#  84975,
#  86665,
#  90103,
#  90399,
#  90785,
#  91339,
#  1730,
#  5119,
#  5307,
#  17500,
#  20935,
#  22456,
#  28219,
#  28338,
#  31425,
#  32353,
#  34552,
#  41533,
#  41851,
#  41890,
#  42803,
#  58914,
#  58999,
#  59320,
#  62483,
#  64002,
#  64846,
#  68728,
#  72723,
#  74550,
#  74663,
#  76648,
#  77057,
#  79037,
#  80250,
#  84164,
#  87045,
#  87066,
#  88311,
#  88883,
#  90741,
#  96152,
#  1021,
#  3820,
#  4018,
#  7401,
#  11850,
#  11975,
#  15712,
#  16523,
#  16942,
#  18524,
#  20147,
#  21367,
#  23323,
#  24979,
#  26738,
#  27341,
#  28019,
#  30812,
#  33317,
#  33497,
#  43945,
#  47118,
#  48174,
#  49336,
#  59308,
#  61431,
#  65668,
#  66317,
#  74082,
#  74932,
#  75528,
#  77691,
#  78777,
#  82672,
#  85023,
#  90346,
#  91028,
#  95848,
#  2551,
#  6517,
#  10317,
#  11375,
#  11483,
#  13205,
#  14106,
#  16190,
#  22468,
#  24852,
#  26619,
#  29847,
#  30195,
#  33966,
#  34193,
#  37903,
#  44833,
#  47051,
#  47584,
#  53563,
#  54269,
#  57700,
#  59022,
#  59466,
#  60589,
#  63483,
#  67930,
#  75049,
#  75318,
#  76963,
#  78375,
#  81530,
#  81614,
#  82189,
#  82375,
#  95123,
#  96404,
#  99092,
#  5032,
#  11253,
#  11619,
#  13449,
#  14512,
#  15724,
#  35418,
#  37352,
#  39148,
#  40595,
#  43925,
#  48918,
#  50955,
#  53292,
#  57353,
#  60903,
#  61716,
#  70289,
#  71579,
#  72593,
#  75327,
#  77642,
#  79927,
#  85646,
#  91348,
#  94650,
#  95588,
#  95758,
#  97687,
#  98203,
#  98487,
#  1928,
#  3583,
#  10658,
#  13408,
#  15918,
#  20292,
#  21119,
#  22841,
#  23198,
#  27480,
#  32623,
#  37589,
#  42147,
#  42454,
#  55786,
#  61038,
#  62438,
#  63125,
#  68472,
#  70022,
#  74031,
#  74968,
#  77153,
#  78893,
#  79178,
#  84002,
#  1868,
#  2303,
#  3634,
#  13992,
#  14033,
#  16797,
#  20613,
#  23081,
#  28690,
#  28780,
#  37588,
#  38121,
#  38276,
#  39902,
#  41172,
#  46829,
#  47998,
#  48036,
#  49967,
#  50677,
#  52925,
#  54801,
#  58966,
#  59785,
#  69199,
#  72024,
#  76452,
#  79111,
#  80686,
#  81150,
#  83123,
#  86075,
#  88812,
#  91940,
#  93781,
#  95996,
#  98081,
#  98269,
#  6815,
#  14049,
#  14515,
#  15157,
#  15552,
#  17224,
#  17379,
#  18585,
#  21274,
#  22208,
#  25297,
#  25487,
#  27049,
#  27844,
#  28629,
#  28779,
#  29919,
#  31900,
#  37949,
#  38759,
#  53726,
#  55178,
#  59679,
#  62571,
#  65140,
#  71642,
#  72253,
#  78885,
#  82835,
#  83943,
#  86735,
#  92125,
#  95462,
#  95478,
#  96823,
#  97252,
#  98849,
#  99228,
#  1880,
#  10008,
#  14445,
#  18342,
#  18624,
#  19544,
#  20713,
#  21106,
#  28270,
#  30189,
#  41614,
#  41658,
#  41906,
#  42453,
#  43371,
#  43741,
#  44734,
#  48045,
#  48180,
#  48416,
#  54013,
#  58730,
#  61008,
#  66670,
#  67679,
#  69057,
#  69489,
#  73298,
#  73875,
#  82660,
#  83380,
#  84735,
#  85487,
#  87377,
#  91480,
#  93067,
#  93681,
#  94189,
#  1614,
#  11874,
#  13514,
#  16820,
#  17333,
#  18005,
#  18067,
#  21595,
#  22536,
#  24063,
#  24254,
#  28034,
#  31359,
#  35364,
#  35497,
#  38952,
#  51830,
#  53924,
#  60183,
#  64461,
#  64491,
#  64558,
#  66049,
#  71270,
#  71952,
#  72237,
#  73633,
#  75337,
#  76083,
#  76212,
#  78228,
#  83810,
#  90192,
#  91242,
#  91803,
#  91828,
#  91961,
#  95093,
#  1238,
#  8878,
#  11597,
#  12005,
#  15061,
#  15843,
#  17349,
#  22234,
#  22646,
#  23497,
#  24210,
#  25748,
#  26116,
#  28116,
#  32316,
#  40878,
#  41370,
#  50115,
#  51162,
#  54217,
#  54501,
#  54690,
#  56988,
#  60140,
#  ...]

# %%
df4 = df2.drop(index=drop_index_list).sort_values(['회사ID','연월'])
df4
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 19588   14271  2015  11  201511   2571840      11  1199495
# 44251   14271  2015  12  201512   3558780      15  1199495
# 39783   14271  2016  01  201601   3358340      15  4257715
# 27519   14271  2016  02  201602   3142340      14  4257715
# 4503    14271  2016  03  201603   3016340      13  4257715
# ...       ...   ...  ..     ...       ...     ...      ...
# 79838  515264  2018  08  201808    763720       5  2422405
# 52591  515264  2018  09  201809    763720       5  2422405
# 94356  515264  2018  10  201810    763720       5  2422405
# 26278  515264  2018  11  201811    763720       5  2422405
# 5181   515264  2018  12  201812    763720       5  2422405
#
#        전년도(기록연도)_대비_매출액_증감률
# 19588                   NaN
# 44251               0.00000
# 39783               2.54959
# 27519               0.00000
# 4503                0.00000
# ...                     ...
# 79838               0.00000
# 52591               0.00000
# 94356               0.00000
# 26278               0.00000
# 5181                0.00000
#
# [15251 rows x 8 columns]

# %%
df4['회사ID'].nunique()
# Out:
# 457

# %%
df4['회사ID'] = df4['회사ID'].astype(str)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15251 entries, 19588 to 5181
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   회사ID                  15251 non-null  object
#  1   년도                    15251 non-null  object
#  2   월                     15251 non-null  object
#  3   연월                    15251 non-null  object
#  4   월별_연금보험료              15251 non-null  int64
#  5   월별_직원수                15251 non-null  int64
#  6   연매출액                  15251 non-null  int64
#  7   전년도(기록연도)_대비_매출액_증감률  14794 non-null  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.0+ MB

# %%
sns.lineplot(data=df4, x='년도',y='연매출액',hue='회사ID')
# Out:
# <AxesSubplot:xlabel='년도', ylabel='연매출액'>

# %%
sns.lineplot(data=df4[df4['연매출액']<(10**10)*0.2], x='년도',y='연매출액',hue='회사ID')
# Out:
# <AxesSubplot:xlabel='년도', ylabel='연매출액'>

# %%
df4.corr()
# Out:
#                       월별_연금보험료    월별_직원수      연매출액  전년도(기록연도)_대비_매출액_증감률
# 월별_연금보험료              1.000000  0.957639  0.849157             -0.003869
# 월별_직원수                0.957639  1.000000  0.744206             -0.004038
# 연매출액                  0.849157  0.744206  1.000000             -0.002200
# 전년도(기록연도)_대비_매출액_증감률 -0.003869 -0.004038 -0.002200              1.000000

# %%
sns.heatmap(data=df4[['연매출액','월별_연금보험료','월별_직원수']].corr(), annot = True ,cmap='RdYlBu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 전처리 방법 고민2 (남은 기업 457개)
# - 연매출 x원 이하인 기업들 제거
# - 직원 수가 감소하거나 직원 수 증가가 더딘 기업들 제거
# - 이미 유니콘기업을 넘어선 기업도 포함되어 있을텐데 어떻게 판단할 지 고민중

# %%
# 연월 데이터가 중간에 누락된 기업이 있는지 확인
df4.groupby('회사ID')[['연월']].count().sort_values(by='연월')
# Out:
#         연월
# 회사ID
# 345099  14
# 226641  17
# 368037  19
# 419895  19
# 183793  20
# ...     ..
# 341779  38
# 419945  48
# 14271   50
# 296819  50
# 134575  50
#
# [457 rows x 1 columns]

# %%
df4[df4['회사ID']=='345099']
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 39219  345099  2015  11  201511    384200       3  1233383
# 20974  345099  2015  12  201512    384200       3  1233383
# 92213  345099  2016  01  201601    384200       3  1529633
# 88252  345099  2016  02  201602    384200       3  1529633
# 12718  345099  2016  03  201603    384200       3  1529633
# 73979  345099  2016  04  201604    384200       3  1529633
# 30361  345099  2017  05  201705    400500       3  2942047
# 59898  345099  2017  06  201706    400500       3  2942047
# 89698  345099  2017  07  201707    400500       3  2942047
# 59709  345099  2017  08  201708    400500       3  2942047
# 32263  345099  2017  09  201709    400500       3  2942047
# 2419   345099  2017  10  201710    400500       3  2942047
# 20386  345099  2017  11  201711    400500       3  2942047
# 43385  345099  2017  12  201712    400500       3  2942047
#
#        전년도(기록연도)_대비_매출액_증감률
# 39219                   NaN
# 20974              0.000000
# 92213              0.240193
# 88252              0.000000
# 12718              0.000000
# 73979              0.000000
# 30361              0.923368
# 59898              0.000000
# 89698              0.000000
# 59709              0.000000
# 32263              0.000000
# 2419               0.000000
# 20386              0.000000
# 43385              0.000000

# %% [markdown]
# #### 연월 데이터가 중간에 누락된 값이 많으니 '년도'별 데이터로 그루핑하여 월별 직원수의 평균값 혹은 중앙값중에 골라서 연도별 직원 수의 증감률 변화를 보자

# %%
df5 = df4.groupby(['회사ID','년도'])[['월별_직원수']].agg(['median','mean']).reset_index()
df5
# Out:
#         회사ID    년도 월별_직원수
#                    median      mean
# 0     123882  2016    6.0  5.666667
# 1     123882  2017    7.5  7.333333
# 2     123882  2018    8.0  7.583333
# 3     124223  2015    7.0  7.000000
# 4     124223  2016    5.0  5.500000
# ...      ...   ...    ...       ...
# 1567  514934  2017    5.5  5.416667
# 1568  514934  2018    7.0  6.750000
# 1569  515264  2016    5.0  5.083333
# 1570  515264  2017    5.0  5.000000
# 1571  515264  2018    5.0  5.000000
#
# [1572 rows x 4 columns]

# %%
df5['직원수_차이'] = df5[('월별_직원수','median')] - df5[('월별_직원수','mean')]

# %%
df5.sort_values(by='직원수_차이')
# Out:
#         회사ID    년도  월별_직원수                  직원수_차이
#                     median         mean
# 641   231090  2017   193.5   219.500000 -26.000000
# 1468  469458  2017  2727.0  2752.250000 -25.250000
# 837   294337  2018  2064.5  2086.583333 -22.083333
# 1470  469473  2016  2104.0  2125.333333 -21.333333
# 19    126538  2018  1258.5  1277.166667 -18.666667
# ...      ...   ...     ...          ...        ...
# 1179  394802  2018    78.0    69.166667   8.833333
# 81    129633  2017    91.0    76.416667  14.583333
# 123   132007  2016    86.5    70.083333  16.416667
# 1175  394749  2018   138.0   116.916667  21.083333
# 1294  419945  2016  3022.5  2945.166667  77.333333
#
# [1572 rows x 5 columns]

# %%
df5['직원수_차이'].mean()
# Out:
# -0.11528468527514325

# %% [markdown]
# - 전체 직원수 차이의 평균은 -0.1수준이지만, 연도별 직원수의 중앙값과 평균값의 차이가 큰 경우가 있다.
#
# #### -아무튼 평균과 중앙값 중에 고르려고 하는데...
#
#
# 2017년에 3개월분의 데이터만 있다고 가정했을 때, 2017-01 10명, 2017-02 10명, 2017-03 70명이라면, 평균으로 따지면 30명, 중앙값은 10명이다.
#
# 2018년에 5개월분의 데이터가 71명, 73명, 75명, 77명, 79명이라면 평균 75명, 중앙값도 75명
#
# 따라서 평균 기준으로 본다면 30명 -> 75명으로 150% 성장, 중앙값 기준으로 본다면 10명 -> 75명으로 750% 성장으로 보임
#
# --------------------------
# 반대로 생각해 보았을 때 한 해 10명 70명 70명이었다가, 다음 해 71명, 73명, 75명, 77명, 79명이 된 경우
#
# 평균 기준으로 본다면 50명 -> 75명으로 50% 성장, 중앙값 기준으로 본다면 70명 -> 75명으로 7.14% 성장
#
# - 그러나 유니콘 기업의 경우 위의 예처럼 한달만에 급격한 직원 증가가 있을 수 있다고 생각함. 따라서 평균으로 보는 것이 좋겠다. (평균이 이상치에 민감하게 반응하기에)

# %%
df5 = df4.groupby(['회사ID','년도'])[['월별_직원수']].mean().reset_index().rename(columns={'월별_직원수':'연평균_직원수'})
df5
# Out:
#         회사ID    년도   연평균_직원수
# 0     123882  2016  5.666667
# 1     123882  2017  7.333333
# 2     123882  2018  7.583333
# 3     124223  2015  7.000000
# 4     124223  2016  5.500000
# ...      ...   ...       ...
# 1567  514934  2017  5.416667
# 1568  514934  2018  6.750000
# 1569  515264  2016  5.083333
# 1570  515264  2017  5.000000
# 1571  515264  2018  5.000000
#
# [1572 rows x 3 columns]

# %%
df5['전년도(기록연도)_대비_직원수_증감률'] = df5.sort_values(['년도']).groupby('회사ID')['연평균_직원수'].pct_change()

# %%
df5 = df5.sort_values(['회사ID','년도'])
df5
# Out:
#         회사ID    년도   연평균_직원수  전년도(기록연도)_대비_직원수_증감률
# 0     123882  2016  5.666667                   NaN
# 1     123882  2017  7.333333              0.294118
# 2     123882  2018  7.583333              0.034091
# 3     124223  2015  7.000000                   NaN
# 4     124223  2016  5.500000             -0.214286
# ...      ...   ...       ...                   ...
# 1567  514934  2017  5.416667             -0.097222
# 1568  514934  2018  6.750000              0.246154
# 1569  515264  2016  5.083333                   NaN
# 1570  515264  2017  5.000000             -0.016393
# 1571  515264  2018  5.000000              0.000000
#
# [1572 rows x 4 columns]

# %% [markdown]
# ## 전처리 고민3
# - 직원수가 매년 지속해서 증가해야만 유니콘 기업인가?
# - 매년 몇%씩 증가해야 유니콘 기업인가?
# - 연평균 최소 직원 수의 기준은 몇명일까?

# %% [markdown]
# - 직원 수가 매해 한번이라도 역성장 했다면?

# %%
drop_id_list = df5[df5['전년도(기록연도)_대비_직원수_증감률'] < 0]['회사ID'].unique().tolist()

# %%
# drop_id_list의 index만 추출
drop_idx_list = []
for num in drop_id_list:
    idx = df4[df4['회사ID'] == num].index.to_list()
    for i in idx:
        drop_idx_list.append(i)

# %%
df6 = df4.drop(index=drop_idx_list).sort_values(['회사ID','년도'])
df6
# Out:
#          회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 3104   123882  2016  01  201601    752560       5   289034
# 71080  123882  2016  02  201602    642320       4   289034
# 19888  123882  2016  03  201603   1069820       6   289034
# 78783  123882  2016  04  201604   1069820       6   289034
# 52795  123882  2016  05  201605   1069820       6   289034
# ...       ...   ...  ..     ...       ...     ...      ...
# 92190  511310  2018  08  201808   6583460      30  4118186
# 89862  511310  2018  09  201809   6763460      31  4118186
# 85068  511310  2018  10  201810   6772460      31  4118186
# 95447  511310  2018  11  201811   6943460      32  4118186
# 10946  511310  2018  12  201812   6943460      32  4118186
#
#        전년도(기록연도)_대비_매출액_증감률
# 3104                    NaN
# 71080                   0.0
# 19888                   0.0
# 78783                   0.0
# 52795                   0.0
# ...                     ...
# 92190                   0.0
# 89862                   0.0
# 85068                   0.0
# 95447                   0.0
# 10946                   0.0
#
# [7117 rows x 8 columns]

# %%
df6['회사ID'].nunique()
# Out:
# 215

# %%
# drop_id_list의 index만 추출
drop_idx_list = []
for num in drop_id_list:
    idx = df5[df5['회사ID'] == num].index.to_list()
    for i in idx:
        drop_idx_list.append(i)

# %%
df5 = df5.drop(index=drop_idx_list).sort_values(['회사ID','년도'])

# %%
df5['회사ID'].nunique()
# Out:
# 215

# %%
# df5와 df6 테이블을 join하자
df7 = pd.merge(df6, df5, how='inner', on=['회사ID','년도'])
df7
# Out:
#         회사ID    년도   월      연월  월별_연금보험료  월별_직원수     연매출액  \
# 0     123882  2016  01  201601    752560       5   289034
# 1     123882  2016  02  201602    642320       4   289034
# 2     123882  2016  03  201603   1069820       6   289034
# 3     123882  2016  04  201604   1069820       6   289034
# 4     123882  2016  05  201605   1069820       6   289034
# ...      ...   ...  ..     ...       ...     ...      ...
# 7112  511310  2018  08  201808   6583460      30  4118186
# 7113  511310  2018  09  201809   6763460      31  4118186
# 7114  511310  2018  10  201810   6772460      31  4118186
# 7115  511310  2018  11  201811   6943460      32  4118186
# 7116  511310  2018  12  201812   6943460      32  4118186
#
#       전년도(기록연도)_대비_매출액_증감률    연평균_직원수  전년도(기록연도)_대비_직원수_증감률
# 0                      NaN   5.666667                   NaN
# 1                      0.0   5.666667                   NaN
# 2                      0.0   5.666667                   NaN
# 3                      0.0   5.666667                   NaN
# 4                      0.0   5.666667                   NaN
# ...                    ...        ...                   ...
# 7112                   0.0  30.250000              0.093373
# 7113                   0.0  30.250000              0.093373
# 7114                   0.0  30.250000              0.093373
# 7115                   0.0  30.250000              0.093373
# 7116                   0.0  30.250000              0.093373
#
# [7117 rows x 10 columns]

# %% [markdown]
# # 전처리 고민4
# - 3년치 이상의 데이터가 있고, 전년 대비 연매출이 지속적으로 상승하며, 전년도 대비 연평균 직원 수가 0명 이상인 기업 215개
# 1. 유니콘의 최소한의 연매출, 최소한의 직원 수로 필터링하고
# 2. 이미 너무 성장한 기업을 배제하자.
# 3. 이후 연매출 증가율 또는 연평균지원수 증가율의 기준을 높여보는 것도 좋을듯

# %%
df7.to_csv('전처리용.csv',encoding='cp949')

# %%
df7 = pd.read_csv('전처리완료.csv', encoding='cp949')

# %%
cond1 = (df7['연매출액']>20000000)
cond2 = (df7['연평균_직원수']>100)
cond3 = (df7['연매출액']>100000000)

# %%
df7[cond1&cond2]['회사ID'].nunique()
# Out:
# 22

# %%
tlist = df7[cond1 & cond2]['회사ID'].unique().tolist()

# %%
index_list = []
for num in tlist:
    idx = df7[df7['회사ID'] == num].index.to_list()
    for i in idx:
        index_list.append(i)

# %%
df7.loc[index_list]
# Out:
#         회사ID    년도   월      연월   월별_연금보험료  월별_직원수       연매출액  \
# 62    126664  2015  11  201511  225166820     740  256505233
# 63    126664  2015  12  201512  225269940     744  256505233
# 64    126664  2016   1  201601  226535440     750  304408150
# 65    126664  2016   2  201602  227341300     757  304408150
# 66    126664  2016   3  201603  227574920     764  304408150
# ...      ...   ...  ..     ...        ...     ...        ...
# 7086  510449  2019   8  201908   30448620     152   28299495
# 7087  510449  2019   9  201909   30440700     154   28299495
# 7088  510449  2019  10  201910   26208980     127   28299495
# 7089  510449  2019  11  201911   25320800     123   28299495
# 7090  510449  2019  12  201912   24001520     117   28299495
#
#       전년도(기록연도)_대비_매출액_증감률     연평균_직원수  전년도(기록연도)_대비_직원수_증감률
# 62                     NaN  742.000000                   NaN
# 63                     NaN  742.000000                   NaN
# 64                0.186752  782.333333              0.054358
# 65                0.186752  782.333333              0.054358
# 66                0.186752  782.333333              0.054358
# ...                    ...         ...                   ...
# 7086              0.125046  145.333333              0.653081
# 7087              0.125046  145.333333              0.653081
# 7088              0.125046  145.333333              0.653081
# 7089              0.125046  145.333333              0.653081
# 7090              0.125046  145.333333              0.653081
#
# [799 rows x 10 columns]
